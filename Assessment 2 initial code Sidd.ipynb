# %% [markdown]
# ## Import Libraries & Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv("Conspan July 24.csv")

# %%
df.head()
# Out:
#    Employee ID   Age              Department  DistanceFromHome  Education  \
# 0           64  25.0              Production                 2        3.0
# 1          339  32.0  Research & Development                 7        4.0
# 2          376  33.0  Research & Development                 9        3.0
# 3          429  36.0                   Sales                18        2.0
# 4          441  32.0  Research & Development                17        3.0
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobRotation  \
# 0                      1.0    Male               3         1            1
# 1                      2.0  Female               4         1            2
# 2                      4.0    Male               2         3            2
# 3                      2.0    Male               2         3            4
# 4                      4.0    Male               3         2            4
#
#    ... RelationshipSatisfaction Tools TotalWorkingYears Training  \
# 0  ...                      3.0     L               6.0        N
# 1  ...                      4.0     L               6.0        Y
# 2  ...                      3.0     L               9.0        Y
# 3  ...                      2.0     H              10.0        Y
# 4  ...                      3.0     L              10.0        Y
#
#    WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0              3.0             2.0                2.0
# 1              3.0             3.0                2.0
# 2              3.0             3.0                2.0
# 3              3.0            10.0                9.0
# 4              2.0             9.0                5.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager Performance
# 0                      0.0                   2.0          47
# 1                      0.0                   2.0          61
# 2                      1.0                   2.0          62
# 3                      9.0                   0.0          82
# 4                      1.0                   6.0          67
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1201 entries, 0 to 1200
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               1201 non-null   int64
#  1   Age                       1199 non-null   float64
#  2   Department                1201 non-null   object
#  3   DistanceFromHome          1201 non-null   int64
#  4   Education                 1198 non-null   float64
#  5   EnvironmentSatisfaction   1199 non-null   float64
#  6   Gender                    1201 non-null   object
#  7   JobInvolvement            1201 non-null   int64
#  8   JobLevel                  1201 non-null   int64
#  9   JobRotation               1201 non-null   int64
#  10  FeedbackFromManager       1200 non-null   object
#  11  Mentoring                 1200 non-null   object
#  12  Autonomy                  1200 non-null   object
#  13  JobRole                   1200 non-null   object
#  14  MonthlyIncome             1190 non-null   float64
#  15  NumCompaniesWorked        1200 non-null   float64
#  16  OverTime                  1200 non-null   object
#  17  PercentSalaryHike         1198 non-null   float64
#  18  RelationshipSatisfaction  1200 non-null   float64
#  19  Tools                     1200 non-null   object
#  20  TotalWorkingYears         1200 non-null   float64
#  21  Training                  1200 non-null   object
#  22  WorkLifeBalance           1199 non-null   float64
#  23  YearsAtCompany            1198 non-null   float64
#  24  YearsInCurrentRole        1198 non-null   float64
#  25  YearsSinceLastPromotion   1198 non-null   float64
#  26  YearsWithCurrManager      1198 non-null   float64
#  27  Performance               1201 non-null   int64
# dtypes: float64(13), int64(6), object(9)
# memory usage: 262.8+ KB

# %% [markdown]
# ## Data Quality Checks

# %%
def summarize_schema(df: pd.DataFrame) -> pd.DataFrame:
    info = []
    for col in df.columns:
        dtype = df[col].dtype
        inferred = pd.api.types.infer_dtype(df[col], skipna=True)
        info.append({
            'column': col,
            'dtype': str(dtype),
            'inferred': inferred,
            'non_null_count': int(df[col].notna().sum()),
            'null_count': int(df[col].isna().sum()),
            'null_pct': float(df[col].isna().mean()*100),
            'n_unique': int(df[col].nunique(dropna=True))
        })
    return pd.DataFrame(info).sort_values(['dtype','column']).reset_index(drop=True)

# %%
def missingness_report(df: pd.DataFrame) -> pd.DataFrame:
    miss = df.isna().mean().sort_values(ascending=False)*100
    return miss.to_frame('missing_pct').reset_index().rename(columns={'index': 'column'})

# %%
def duplicate_report(df: pd.DataFrame) -> pd.DataFrame:
    dup_rows = df.duplicated(keep=False)
    n_dups = int(dup_rows.sum())
    return pd.DataFrame({'metric':['duplicate_rows'], 'value':[n_dups]})

# %%
def numeric_outlier_summary(df: pd.DataFrame) -> pd.DataFrame:
    num_cols = df.select_dtypes(include=[np.number]).columns
    rows = []
    for col in num_cols:
        s = df[col].dropna()
        if s.empty:
            rows.append({'column': col, 'lower_bound': np.nan, 'upper_bound': np.nan,
                         'outlier_count': 0, 'outlier_pct': 0.0})
            continue
        q1 = s.quantile(0.25)
        q3 = s.quantile(0.75)
        iqr = q3 - q1
        lower = q1 - 1.5*iqr
        upper = q3 + 1.5*iqr
        mask = (df[col] < lower) | (df[col] > upper)
        rows.append({
            'column': col,
            'lower_bound': float(lower),
            'upper_bound': float(upper),
            'outlier_count': int(mask.sum()),
            'outlier_pct': float(mask.mean()*100)
        })
    return pd.DataFrame(rows)

# %%
def detect_numeric_strings(df: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for col in df.columns:
        if df[col].dtype == 'object':
            s = df[col].astype(str).str.strip()
            s_repl = s.replace({'': np.nan, 'nan': np.nan, 'None': np.nan})
            numeric_like = s_repl.str.match(r'^[-+]?\\d+(\\.\\d+)?$')
            n_numeric_like = int(numeric_like.fillna(False).sum())
            rows.append({
                'column': col,
                'object_numeric_like': n_numeric_like,
                'object_total': int(len(s)),
                'numeric_like_pct': float(numeric_like.mean(skipna=True)*100 if numeric_like.notna().any() else 0.0)
            })
    return pd.DataFrame(rows)

# %%
def string_quality(df: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for col in df.select_dtypes(include=['object']).columns:
        s = df[col].astype(str)
        lens = s.str.len()
        leading_ws = s.str.match(r'^\\s').sum()
        trailing_ws = s.str.match(r'.*\\s$').sum()
        non_printable = s.str.contains(r'[^\\x20-\\x7E\\n\\r\\t]', regex=True).sum()
        rows.append({
            'column': col,
            'min_len': int(lens.min()),
            'p5_len': float(lens.quantile(0.05)),
            'median_len': float(lens.median()),
            'p95_len': float(lens.quantile(0.95)),
            'max_len': int(lens.max()),
            'leading_ws_count': int(leading_ws),
            'trailing_ws_count': int(trailing_ws),
            'non_printable_count': int(non_printable)
        })
    return pd.DataFrame(rows)

# %%
def cardinality_report(df: pd.DataFrame, high_card_threshold: int = 50) -> pd.DataFrame:
    rows = []
    for col in df.columns:
        nunique = int(df[col].nunique(dropna=True))
        rows.append({'column': col, 'unique': nunique, 'high_cardinality': bool(nunique > high_card_threshold)})
    return pd.DataFrame(rows).sort_values('unique', ascending=False).reset_index(drop=True)

# %%
def numeric_summary(df: pd.DataFrame) -> pd.DataFrame:
    num = df.select_dtypes(include=[np.number])
    if num.empty:
        return pd.DataFrame()
    desc = num.describe(percentiles=[0.01,0.05,0.25,0.5,0.75,0.95,0.99]).T
    desc['missing_pct'] = 100*(1 - desc['count']/len(df))
    return desc.reset_index().rename(columns={'index':'column'})

# %%
schema = summarize_schema(df)
missing = missingness_report(df)
dups = duplicate_report(df)
outliers = numeric_outlier_summary(df)
numstr = detect_numeric_strings(df)
strq = string_quality(df)
card = cardinality_report(df)
numsum = numeric_summary(df)
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_32728\3950004592.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   n_numeric_like = int(numeric_like.fillna(False).sum())
# C:\Users\siddh\AppData\Local\Temp\ipykernel_32728\3950004592.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   n_numeric_like = int(numeric_like.fillna(False).sum())
# C:\Users\siddh\AppData\Local\Temp\ipykernel_32728\3950004592.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   n_numeric_like = int(numeric_like.fillna(False).sum())
# C:\Users\siddh\AppData\Local\Temp\ipykernel_32728\3950004592.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   n_numeric_like = int(numeric_like.fillna(False).sum())
# C:\Users\siddh\AppData\Local\Temp\ipykernel_32728\3950004592.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   n_numeric_like = int(numeric_like.fillna(False).sum())
# C:\Users\siddh\AppData\Local\Temp\ipykernel_32728\3950004592.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   n_numeric_like = int(numeric_like.fillna(False).sum())
# C:\Users\siddh\AppData\Local\Temp\ipykernel_32728\3950004592.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   n_numeric_like = int(numeric_like.fillna(False).sum())

# %%
missing_show = missing
missing_show['missing_pct'] = missing_show['missing_pct'].round(2)
missing_show
# Out:
#                       column  missing_pct
# 0              MonthlyIncome         0.92
# 1                  Education         0.25
# 2          PercentSalaryHike         0.25
# 3       YearsWithCurrManager         0.25
# 4             YearsAtCompany         0.25
# 5         YearsInCurrentRole         0.25
# 6    YearsSinceLastPromotion         0.25
# 7            WorkLifeBalance         0.17
# 8    EnvironmentSatisfaction         0.17
# 9                        Age         0.17
# 10                 Mentoring         0.08
# 11       FeedbackFromManager         0.08
# 12                     Tools         0.08
# 13  RelationshipSatisfaction         0.08
# 14                  OverTime         0.08
# 15        NumCompaniesWorked         0.08
# 16                  Autonomy         0.08
# 17                  Training         0.08
# 18         TotalWorkingYears         0.08
# 19                   JobRole         0.08
# 20                  JobLevel         0.00
# 21               JobRotation         0.00
# 22                    Gender         0.00
# 23            JobInvolvement         0.00
# 24                Department         0.00
# 25               Employee ID         0.00
# 26          DistanceFromHome         0.00
# 27               Performance         0.00

# %%
plt.figure(figsize=(10,4))
missing.set_index('column')['missing_pct'].plot(kind='bar', color='#d95f02')
plt.ylabel('Missing %')
plt.title('Missingness by Column')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10,6))
sns.heatmap(df.isna(), cbar=False)
plt.title('Missingness Heatmap')
plt.tight_layout()
plt.show()

# %%
num_cols = [col for col in df.select_dtypes(include=[np.number]).columns if col != 'Employee ID']
if num_cols:
    num_rows = math.ceil(len(num_cols) / 6)
    fig, axes = plt.subplots(num_rows, 6, figsize=(5 * 4, num_rows * 4))
    axes = axes.flatten()
    for i, col in enumerate(num_cols):
        sns.histplot(df[col], bins=30, kde=True, ax=axes[i], color='#1b9e77')
        axes[i].set_title(f'{col} distribution', fontsize=12)
        axes[i].tick_params(axis='both', which='major', labelsize=10)
    for j in range(len(num_cols), len(axes)):
        axes[j].set_visible(False)
    plt.tight_layout(pad=3.0); plt.show()

    fig, axes = plt.subplots(len(num_cols), 1, figsize=(8, 3*len(num_cols)))
    if len(num_cols) == 1: axes = [axes]
    for ax, col in zip(axes, num_cols):
        sns.boxplot(x=df[col], ax=ax, color='#7570b3')
        ax.set_title(f'{col} boxplot')
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='TotalWorkingYears', y='YearsAtCompany', alpha=0.6)
plt.plot([0, df['TotalWorkingYears'].max()], [0, df['TotalWorkingYears'].max()], color='red', linestyle='--')
plt.title('Sanity Check: Years at Company vs. Total Working Years')
plt.xlabel('Total Working Years')
plt.ylabel('Years at Company')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='YearsAtCompany', y='YearsInCurrentRole', alpha=0.6)
plt.plot([0, df['YearsAtCompany'].max()], [0, df['YearsAtCompany'].max()], color='red', linestyle='--')
plt.title('Sanity Check: Years in Current Role vs. Years at Company')
plt.xlabel('Years at Company')
plt.ylabel('Years in Current Role')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Age', y='TotalWorkingYears', alpha=0.6)
plt.plot([18, 100], [0, 82], color='red', linestyle='--')
plt.title('Sanity Check: Total Working Years vs. Age')
plt.xlabel('Age')
plt.ylabel('Total Working Years')
plt.xlim(0, 40)
plt.ylim(0, 40)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Data Cleaning using Data Dict

# %%
data_dict = {
    "EmployeeID": {"type": "int"},
    "Age": {"min": 18, "max": 60},
    "Department": {"allowed": ["Human Resources", "IT Support", "Production","Research and Development", "Finance", "Sales"]},
    "DistanceFromHome": {"min": 1, "max": 25},
    "Education": {"min": 1, "max": 5},
    "EnvironmentSatisfaction": {"min": 1, "max": 4},
    "Gender": {"allowed": ["Male", "Female"]},
    "JobInvolvement": {"min": 1, "max": 4},
    "JobLevel": {"min": 1, "max": 5},
    "JobRole": {"type": "string"},
    "JobRotation": {"min": 1, "max": 4},
    "FeedbackFromManager": {"allowed": ["H", "L"]},
    "Mentoring": {"allowed": ["Y", "N"]},
    "MonthlyIncome": {"min": 0, "max": None},
    "NumCompaniesWorked": {"min": 0, "max": None},
    "OverTime": {"allowed": ["Yes", "No"]},
    "Performance": {"min": 0, "max": 100},
    "PercentSalaryHike": {"min": 0, "max": 100},
    "RelationshipSatisfaction": {"min": 1, "max": 4},
    "TotalWorkingYears": {"min": 0, "max": None},
    "WorkLifeBalance": {"min": 1, "max": 4},
    "YearsAtCompany": {"min": 0, "max": None},
    "YearsInCurrentRole": {"min": 0, "max": None},
    "YearsSinceLastPromotion": {"min": 0, "max": None},
    "YearsWithCurrManager": {"min": 0, "max": None},
    "Autonomy": {"allowed": ["H", "L"]},
    "Tools": {"allowed": ["L", "H"]},
    "Training": {"allowed": ["Y", "N"]}
}

# %%
def validate_dataframe(df, data_dict):
    invalid_flags = pd.DataFrame(False, index=df.index, columns=df.columns)

    for col, rules in data_dict.items():
        if col not in df.columns:
            continue

        if "min" in rules or "max" in rules:
            if "min" in rules and rules["min"] is not None:
                invalid_flags[col] |= df[col] < rules["min"]
            if "max" in rules and rules["max"] is not None:
                invalid_flags[col] |= df[col] > rules["max"]

        if "allowed" in rules:
            invalid_flags[col] |= ~df[col].isin(rules["allowed"])

    return invalid_flags

# %%
invalids = validate_dataframe(df, data_dict)
invalids
# Out:
#       Employee ID    Age  Department  DistanceFromHome  Education  \
# 0           False  False       False             False      False
# 1           False  False        True             False      False
# 2           False  False        True             False      False
# 3           False  False       False             False      False
# 4           False  False        True             False      False
# ...           ...    ...         ...               ...        ...
# 1196        False  False       False             False      False
# 1197        False  False        True             False      False
# 1198        False  False        True             False      False
# 1199        False  False       False             False      False
# 1200        False  False       False             False      False
#
#       EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobRotation  \
# 0                       False   False           False     False        False
# 1                       False   False           False     False        False
# 2                       False   False           False     False        False
# 3                       False   False           False     False        False
# 4                       False   False           False     False        False
# ...                       ...     ...             ...       ...          ...
# 1196                    False   False           False     False        False
# 1197                    False   False           False     False        False
# 1198                    False   False           False     False        False
# 1199                    False   False           False     False        False
# 1200                    False   False           False     False        False
#
#       ...  RelationshipSatisfaction  Tools  TotalWorkingYears  Training  \
# 0     ...                     False  False              False     False
# 1     ...                     False  False              False     False
# 2     ...                     False  False              False     False
# 3     ...                     False  False              False     False
# 4     ...                     False  False              False     False
# ...   ...                       ...    ...                ...       ...
# 1196  ...                     False  False              False     False
# 1197  ...                     False  False              False     False
# 1198  ...                     False  False              False     False
# 1199  ...                     False  False              False     False
# 1200  ...                     False  False              False     False
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0               False           False               False
# 1               False           False               False
# 2               False           False               False
# 3               False           False               False
# 4               False           False               False
# ...               ...             ...                 ...
# 1196            False           False               False
# 1197            False           False               False
# 1198            False           False               False
# 1199            False           False               False
# 1200            False           False               False
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Performance
# 0                       False                 False        False
# 1                       False                 False        False
# 2                       False                 False        False
# 3                       False                 False        False
# 4                       False                 False        False
# ...                       ...                   ...          ...
# 1196                    False                 False        False
# 1197                    False                 False        False
# 1198                    False                 False        False
# 1199                    False                 False        False
# 1200                    False                 False        False
#
# [1201 rows x 28 columns]

# %%
rows_with_issues = df[invalids.any(axis=1)]
rows_with_issues
# Out:
#       Employee ID   Age              Department  DistanceFromHome  Education  \
# 0              64  25.0              Production                 2        3.0
# 1             339  32.0  Research & Development                 7        4.0
# 2             376  33.0  Research & Development                 9        3.0
# 3             429  36.0                   Sales                18        2.0
# 4             441  32.0  Research & Development                17        3.0
# ...           ...   ...                     ...               ...        ...
# 1196        77703  38.0         Human Resources                 6        3.0
# 1197        77743  39.0  Research & Development                10        1.0
# 1198        78090  56.0  Research & Development                20        3.0
# 1199        78175  38.0                   Sales                15        2.0
# 1200        78280  46.0              Production                 9        3.0
#
#       EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobRotation  \
# 0                         1.0    Male               3         1            1
# 1                         2.0  Female               4         1            2
# 2                         4.0    Male               2         3            2
# 3                         2.0    Male               2         3            4
# 4                         4.0    Male               3         2            4
# ...                       ...     ...             ...       ...          ...
# 1196                      1.0    Male               3         1            2
# 1197                      4.0  Female               2         4            2
# 1198                      1.0  Female               3         1            1
# 1199                      2.0  Female               3         2            2
# 1200                      2.0  Female               3         1            4
#
#       ... RelationshipSatisfaction Tools TotalWorkingYears Training  \
# 0     ...                      3.0     L               6.0        N
# 1     ...                      4.0     L               6.0        Y
# 2     ...                      3.0     L               9.0        Y
# 3     ...                      2.0     H              10.0        Y
# 4     ...                      3.0     L              10.0        Y
# ...   ...                      ...   ...               ...      ...
# 1196  ...                      4.0     H              13.0        Y
# 1197  ...                      3.0     L              21.0        Y
# 1198  ...                      2.0     L              18.0        N
# 1199  ...                      4.0     L              11.0        Y
# 1200  ...                      2.0     H               9.0        N
#
#       WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                 3.0             2.0                2.0
# 1                 3.0             3.0                2.0
# 2                 3.0             3.0                2.0
# 3                 3.0            10.0                9.0
# 4                 2.0             9.0                5.0
# ...               ...             ...                ...
# 1196              3.0            11.0               10.0
# 1197              3.0            21.0                6.0
# 1198              3.0             5.0                4.0
# 1199              3.0             7.0                7.0
# 1200              1.0             7.0                5.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager Performance
# 0                         0.0                   2.0          47
# 1                         0.0                   2.0          61
# 2                         1.0                   2.0          62
# 3                         9.0                   0.0          82
# 4                         1.0                   6.0          67
# ...                       ...                   ...         ...
# 1196                      3.0                   8.0          70
# 1197                     11.0                   8.0          60
# 1198                      0.0                   3.0          35
# 1199                      1.0                   7.0          73
# 1200                      2.0                   5.0          31
#
# [1201 rows x 28 columns]

# %%
def summarize_invalids(df, invalid_flags):
    summary = {}
    for col in df.columns:
        if col in invalid_flags.columns:
            invalid_count = invalid_flags[col].sum()
            if invalid_count > 0:
                summary[col] = {
                    "invalid_count": invalid_count,
                    "total_rows": len(df),
                    "percent_invalid": round((invalid_count / len(df)) * 100, 2)
                }
    return pd.DataFrame(summary).T.sort_values("percent_invalid", ascending=False)

# %%
invalids = validate_dataframe(df, data_dict)
summary = summarize_invalids(df, invalids)
summary
# Out:
#                      invalid_count  total_rows  percent_invalid
# Autonomy                    1201.0      1201.0           100.00
# Department                   489.0      1201.0            40.72
# Age                            2.0      1201.0             0.17
# Performance                    2.0      1201.0             0.17
# Mentoring                      1.0      1201.0             0.08
# FeedbackFromManager            1.0      1201.0             0.08
# OverTime                       1.0      1201.0             0.08
# Tools                          1.0      1201.0             0.08
# Training                       1.0      1201.0             0.08
# YearsAtCompany                 1.0      1201.0             0.08

# %%
df.head()
# Out:
#    Employee ID   Age              Department  DistanceFromHome  Education  \
# 0           64  25.0              Production                 2        3.0
# 1          339  32.0  Research & Development                 7        4.0
# 2          376  33.0  Research & Development                 9        3.0
# 3          429  36.0                   Sales                18        2.0
# 4          441  32.0  Research & Development                17        3.0
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobRotation  \
# 0                      1.0    Male               3         1            1
# 1                      2.0  Female               4         1            2
# 2                      4.0    Male               2         3            2
# 3                      2.0    Male               2         3            4
# 4                      4.0    Male               3         2            4
#
#    ... RelationshipSatisfaction Tools TotalWorkingYears Training  \
# 0  ...                      3.0     L               6.0        N
# 1  ...                      4.0     L               6.0        Y
# 2  ...                      3.0     L               9.0        Y
# 3  ...                      2.0     H              10.0        Y
# 4  ...                      3.0     L              10.0        Y
#
#    WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0              3.0             2.0                2.0
# 1              3.0             3.0                2.0
# 2              3.0             3.0                2.0
# 3              3.0            10.0                9.0
# 4              2.0             9.0                5.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager Performance
# 0                      0.0                   2.0          47
# 1                      0.0                   2.0          61
# 2                      1.0                   2.0          62
# 3                      9.0                   0.0          82
# 4                      1.0                   6.0          67
#
# [5 rows x 28 columns]

# %% [markdown]
# Autonomy has "Y/N" values per the dataset, but the data dictionary specifies "H/L" values. Discuss w/ team.

# %%
df.loc[~df["Department"].isin(data_dict["Department"]["allowed"]), "Department"].unique().tolist()
# Out:
# ['Research & Development', 'IT_Support', 'R&D', 'Fin']

# %%
print(data_dict["Department"]["allowed"])
# Out:
# ['Human Resources', 'IT Support', 'Production', 'Research and Development', 'Finance', 'Sales']

# %% [markdown]
# Invalid departments are just abbreviations or minor typos. Can be replaced.

# %%
autonomy_corrections = {
    "Y": "H",
    "N": "L"
}
df["Autonomy"] = df["Autonomy"].replace(autonomy_corrections)

# %%
dept_corrections = {
    "Research & Development": "Research and Development",
    "IT_Support": "IT Support",
    "R&D": "Research and Development",
    "Fin": "Finance"
}

df["Department"] = df["Department"].replace(dept_corrections)

# %%
invalids = validate_dataframe(df, data_dict)
summary = summarize_invalids(df, invalids)
summary
# Out:
#                      invalid_count  total_rows  percent_invalid
# Age                            2.0      1201.0             0.17
# Performance                    2.0      1201.0             0.17
# FeedbackFromManager            1.0      1201.0             0.08
# Autonomy                       1.0      1201.0             0.08
# Mentoring                      1.0      1201.0             0.08
# OverTime                       1.0      1201.0             0.08
# Tools                          1.0      1201.0             0.08
# Training                       1.0      1201.0             0.08
# YearsAtCompany                 1.0      1201.0             0.08

# %%
df.sort_values(by="Age", ascending=False)
# Out:
#       Employee ID    Age                Department  DistanceFromHome  \
# 1102        71078  530.0                   Finance                 7
# 174         10330  159.0                     Sales                13
# 800         50946   60.0  Research and Development                12
# 574         35469   60.0                     Sales                21
# 1168        75928   59.0                     Sales                 6
# ...           ...    ...                       ...               ...
# 869         54542   18.0                Production                14
# 150          8724   18.0                     Sales                 7
# 1121        72255   18.0                     Sales                10
# 532         32344    NaN  Research and Development                 3
# 1067        68388    NaN  Research and Development                10
#
#       Education  EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 1102        3.0                      2.0    Male               2         3
# 174         2.0                      2.0    Male               3         3
# 800         3.0                      1.0  Female               3         5
# 574         4.0                      1.0    Male               3         2
# 1168        3.0                      1.0  Female               3         3
# ...         ...                      ...     ...             ...       ...
# 869         1.0                      3.0    Male               3         1
# 150         2.0                      2.0  Female               3         1
# 1121        3.0                      4.0  Female               2         1
# 532         3.0                      1.0    Male               2         2
# 1067        3.0                      1.0    Male               3         3
#
#       JobRotation  ... RelationshipSatisfaction Tools TotalWorkingYears  \
# 1102            2  ...                      4.0     L              10.0
# 174             2  ...                      3.0     L              14.0
# 800             2  ...                      4.0     L              33.0
# 574             1  ...                      4.0     L              10.0
# 1168            1  ...                      4.0     H              28.0
# ...           ...  ...                      ...   ...               ...
# 869             1  ...                      4.0     L               0.0
# 150             2  ...                      3.0     L               0.0
# 1121            2  ...                      1.0     L               0.0
# 532             2  ...                      4.0     L              19.0
# 1067            4  ...                      2.0     L              25.0
#
#      Training  WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1102        N              1.0             8.0                2.0
# 174         Y              1.0             6.0                4.0
# 800         N              1.0            29.0                8.0
# 574         N              3.0             2.0                2.0
# 1168        N              2.0            21.0               16.0
# ...       ...              ...             ...                ...
# 869         Y              3.0             0.0                0.0
# 150         Y              4.0             0.0                0.0
# 1121        N              3.0             0.0                0.0
# 532         Y              3.0             2.0                2.0
# 1067        Y              3.0            17.0               14.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager Performance
# 1102                      2.0                   6.0          50
# 174                       0.0                   4.0          66
# 800                      11.0                  10.0          44
# 574                       2.0                   2.0          32
# 1168                      7.0                   9.0          68
# ...                       ...                   ...         ...
# 869                       0.0                   0.0          55
# 150                       0.0                   0.0          50
# 1121                      0.0                   0.0          45
# 532                       2.0                   2.0          53
# 1067                     12.0                  11.0          64
#
# [1201 rows x 28 columns]

# %%
valid_rows_mask = pd.Series(True, index=df.index)

# 2. Loop through the rules and update the mask
for column, rules in data_dict.items():
    if column in df.columns:
        if 'min' in rules and rules['min'] is not None:
            valid_rows_mask &= (df[column] >= rules['min'])
        if 'max' in rules and rules['max'] is not None:
            valid_rows_mask &= (df[column] <= rules['max'])
        if 'allowed' in rules:
            valid_rows_mask &= (df[column].isin(rules['allowed']))

# 3. Create the new, filtered DataFrame
filtered_df = df[valid_rows_mask].copy()

# Optional: See how many rows were removed
print(f"Original DataFrame shape: {df.shape}")
print(f"Filtered DataFrame shape: {filtered_df.shape}")
# Out:
# Original DataFrame shape: (1201, 28)
# Filtered DataFrame shape: (1172, 28)

# %%
filtered_df.head()
# Out:
#    Employee ID   Age                Department  DistanceFromHome  Education  \
# 0           64  25.0                Production                 2        3.0
# 1          339  32.0  Research and Development                 7        4.0
# 2          376  33.0  Research and Development                 9        3.0
# 3          429  36.0                     Sales                18        2.0
# 4          441  32.0  Research and Development                17        3.0
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobRotation  \
# 0                      1.0    Male               3         1            1
# 1                      2.0  Female               4         1            2
# 2                      4.0    Male               2         3            2
# 3                      2.0    Male               2         3            4
# 4                      4.0    Male               3         2            4
#
#    ... RelationshipSatisfaction Tools TotalWorkingYears Training  \
# 0  ...                      3.0     L               6.0        N
# 1  ...                      4.0     L               6.0        Y
# 2  ...                      3.0     L               9.0        Y
# 3  ...                      2.0     H              10.0        Y
# 4  ...                      3.0     L              10.0        Y
#
#    WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0              3.0             2.0                2.0
# 1              3.0             3.0                2.0
# 2              3.0             3.0                2.0
# 3              3.0            10.0                9.0
# 4              2.0             9.0                5.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager Performance
# 0                      0.0                   2.0          47
# 1                      0.0                   2.0          61
# 2                      1.0                   2.0          62
# 3                      9.0                   0.0          82
# 4                      1.0                   6.0          67
#
# [5 rows x 28 columns]

# %%
filtered_out_df = df[~valid_rows_mask].copy()
reasons_for_filtering = []

for index, row in filtered_out_df.iterrows():
    reasons = []
    for column, rules in data_dict.items():
        if column in df.columns:
            if 'min' in rules and rules['min'] is not None and row[column] < rules['min']:
                reasons.append(f"{column} ({row[column]}) < min ({rules['min']})")
            if 'max' in rules and rules['max'] is not None and row[column] > rules['max']:
                reasons.append(f"{column} ({row[column]}) > max ({rules['max']})")
            if 'allowed' in rules and row[column] not in rules['allowed']:
                reasons.append(f"{column} ('{row[column]}') not in allowed list")

    reasons_for_filtering.append("; ".join(reasons))

filtered_out_df['Reason_for_Filtering'] = reasons_for_filtering

print(f"Found {len(filtered_out_df)} invalid rows.")
display(filtered_out_df.head())
# Out:
# Found 29 invalid rows.
#      Employee ID    Age                Department  DistanceFromHome  \
# 16          1094   56.0  Research and Development                15
# 97          6100   45.0                   Finance                 4
# 101         6352   30.0                     Sales                 7
# 144         8495   33.0                     Sales                 9
# 174        10330  159.0                     Sales                13
#
#      Education  EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 16         4.0                      4.0  Female               3         5
# 97         3.0                      2.0    Male               2         2
# 101        1.0                      3.0    Male               3         1
# 144        1.0                      2.0  Female               3         2
# 174        2.0                      2.0    Male               3         3
#
#      JobRotation  ... Tools TotalWorkingYears Training WorkLifeBalance  \
# 16             2  ...     L              28.0        Y             3.0
# 97             4  ...     L               8.0        N             NaN
# 101            2  ...     L               1.0        Y             3.0
# 144            1  ...     L               7.0        N             1.0
# 174            2  ...     L              14.0        Y             1.0
#
#      YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 16              5.0                 2.0                     4.0
# 97              NaN                 NaN                     NaN
# 101             1.0                 0.0                     0.0
# 144             2.0                 4.0                     3.0
# 174             6.0                 4.0                     0.0
#
#      YearsWithCurrManager  Performance           Reason_for_Filtering
# 16                    2.0          161  Performance (161) > max (100)
# 97                    NaN           32
# 101                   0.0          -59    Performance (-59) < min (0)
# 144                   7.0           73
# 174                   4.0           66         Age (159.0) > max (60)
#
# [5 rows x 29 columns]

# %%
filtered_out_df
# Out:
#       Employee ID    Age                Department  DistanceFromHome  \
# 16           1094   56.0  Research and Development                15
# 97           6100   45.0                   Finance                 4
# 101          6352   30.0                     Sales                 7
# 144          8495   33.0                     Sales                 9
# 174         10330  159.0                     Sales                13
# 176         10361   27.0                IT Support                 6
# 195         11061   27.0  Research and Development                 7
# 239         14948   32.0  Research and Development                10
# 255         16145   34.0  Research and Development                 8
# 282         17522   37.0  Research and Development                 4
# 394         24403   29.0                Production                 7
# 411         25883   43.0  Research and Development                14
# 456         29086   45.0                   Finance                21
# 532         32344    NaN  Research and Development                 3
# 536         32889   44.0                   Finance                20
# 569         35156   37.0                IT Support                10
# 594         37873   27.0                     Sales                 9
# 616         39490   26.0                IT Support                 9
# 654         41662   29.0                   Finance                19
# 691         44117   27.0  Research and Development                 4
# 773         49494   43.0  Research and Development                15
# 811         51302   24.0  Research and Development                21
# 846         53176   45.0                     Sales                18
# 1030        65786   43.0  Research and Development                 7
# 1034        65975   24.0                     Sales                16
# 1067        68388    NaN  Research and Development                10
# 1090        70117   25.0  Research and Development                 5
# 1102        71078  530.0                   Finance                 7
# 1140        74040   30.0                IT Support                 4
#
#       Education  EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 16          4.0                      4.0  Female               3         5
# 97          3.0                      2.0    Male               2         2
# 101         1.0                      3.0    Male               3         1
# 144         1.0                      2.0  Female               3         2
# 174         2.0                      2.0    Male               3         3
# 176         2.0                      3.0  Female               2         3
# 195         4.0                      4.0    Male               2         4
# 239         4.0                      3.0    Male               2         3
# 255         4.0                      1.0    Male               3         3
# 282         2.0                      2.0  Female               4         5
# 394         2.0                      4.0    Male               2         2
# 411         2.0                      2.0    Male               3         4
# 456         NaN                      1.0    Male               3         3
# 532         3.0                      1.0    Male               2         2
# 536         4.0                      1.0    Male               3         3
# 569         3.0                      2.0    Male               3         4
# 594         3.0                      4.0    Male               3         2
# 616         1.0                      4.0    Male               4         3
# 654         3.0                      1.0    Male               3         2
# 691         2.0                      3.0  Female               3         3
# 773         3.0                      3.0    Male               1         5
# 811         NaN                      NaN    Male               4         1
# 846         2.0                      3.0  Female               3         2
# 1030        1.0                      4.0    Male               4         3
# 1034        NaN                      NaN    Male               3         1
# 1067        3.0                      1.0    Male               3         3
# 1090        1.0                      4.0    Male               2         2
# 1102        3.0                      2.0    Male               2         3
# 1140        2.0                      3.0    Male               4         2
#
#       JobRotation  ... Tools TotalWorkingYears Training WorkLifeBalance  \
# 16              2  ...     L              28.0        Y             3.0
# 97              4  ...     L               8.0        N             NaN
# 101             2  ...     L               1.0        Y             3.0
# 144             1  ...     L               7.0        N             1.0
# 174             2  ...     L              14.0        Y             1.0
# 176             3  ...     H              10.0        Y             3.0
# 195             3  ...     H              10.0        N             1.0
# 239             2  ...     H               6.0        Y             2.0
# 255             3  ...     L              12.0        Y             2.0
# 282             1  ...     L               8.0        Y             1.0
# 394             1  ...     H              10.0        N             3.0
# 411             2  ...     L              22.0        N             3.0
# 456             2  ...     H               9.0        Y             1.0
# 532             2  ...     L              19.0        Y             3.0
# 536             1  ...     H               6.0        Y             1.0
# 569             2  ...     L              10.0        Y             2.0
# 594             2  ...     H               5.0      NaN             3.0
# 616             3  ...     L               7.0        N             1.0
# 654             2  ...     H               8.0        Y             2.0
# 691             3  ...   NaN               NaN        Y             3.0
# 773             2  ...     L              25.0        Y             3.0
# 811             2  ...     L               6.0        Y             3.0
# 846             4  ...     H               9.0        Y             NaN
# 1030            1  ...     L               7.0        N             3.0
# 1034            2  ...     L               3.0        N             3.0
# 1067            4  ...     L              25.0        Y             3.0
# 1090            2  ...     L               6.0        N             3.0
# 1102            2  ...     L              10.0        N             1.0
# 1140            2  ...     H               6.0        Y             3.0
#
#       YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 16               5.0                 2.0                     4.0
# 97               NaN                 NaN                     NaN
# 101              1.0                 0.0                     0.0
# 144              2.0                 4.0                     3.0
# 174              6.0                 4.0                     0.0
# 176             10.0                 7.0                     1.0
# 195              9.0                 5.0                     3.0
# 239              4.0                 4.0                     2.0
# 255              1.0                 0.0                     0.0
# 282              8.0                 5.0                     2.0
# 394              4.0                 3.0                     0.0
# 411             -4.0                 1.0                     1.0
# 456              8.0                 2.0                     1.0
# 532              2.0                 2.0                     2.0
# 536              4.0                 6.0                     2.0
# 569             10.0                 4.0                     2.0
# 594              5.0                 4.0                     0.0
# 616              3.0                 5.0                     1.0
# 654              8.0                 6.0                     3.0
# 691              9.0                 7.0                     0.0
# 773              NaN                 NaN                     NaN
# 811              6.0                 5.0                     1.0
# 846              NaN                 NaN                     NaN
# 1030             0.0                 0.0                     0.0
# 1034             2.0                 2.0                     2.0
# 1067            17.0                14.0                    12.0
# 1090             2.0                 2.0                     2.0
# 1102             8.0                 2.0                     2.0
# 1140             2.0                 2.0                     2.0
#
#       YearsWithCurrManager  Performance  \
# 16                     2.0          161
# 97                     NaN           32
# 101                    0.0          -59
# 144                    7.0           73
# 174                    4.0           66
# 176                    7.0           80
# 195                    2.0           63
# 239                    6.0           70
# 255                    0.0           80
# 282                    5.0           69
# 394                    3.0           38
# 411                    0.0           41
# 456                    6.0           32
# 532                    2.0           53
# 536                    7.0           34
# 569                    6.0           68
# 594                    4.0           70
# 616                    6.0           69
# 654                    5.0           40
# 691                    7.0           75
# 773                    NaN           66
# 811                    4.0           59
# 846                    NaN           69
# 1030                   0.0           74
# 1034                   1.0           44
# 1067                  11.0           64
# 1090                   2.0           63
# 1102                   6.0           50
# 1140                   3.0           76
#
#                                    Reason_for_Filtering
# 16                        Performance (161) > max (100)
# 97
# 101                         Performance (-59) < min (0)
# 144
# 174                              Age (159.0) > max (60)
# 176
# 195
# 239
# 255
# 282
# 394   FeedbackFromManager ('nan') not in allowed lis...
# 411                     YearsAtCompany (-4.0) < min (0)
# 456
# 532
# 536
# 569
# 594                Training ('nan') not in allowed list
# 616
# 654
# 691   OverTime ('nan') not in allowed list; Tools ('...
# 773
# 811
# 846
# 1030
# 1034
# 1067
# 1090
# 1102                             Age (530.0) > max (60)
# 1140
#
# [29 rows x 29 columns]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1172 entries, 0 to 1200
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               1172 non-null   int64
#  1   Age                       1172 non-null   float64
#  2   Department                1172 non-null   object
#  3   DistanceFromHome          1172 non-null   int64
#  4   Education                 1172 non-null   float64
#  5   EnvironmentSatisfaction   1172 non-null   float64
#  6   Gender                    1172 non-null   object
#  7   JobInvolvement            1172 non-null   int64
#  8   JobLevel                  1172 non-null   int64
#  9   JobRotation               1172 non-null   int64
#  10  FeedbackFromManager       1172 non-null   object
#  11  Mentoring                 1172 non-null   object
#  12  Autonomy                  1172 non-null   object
#  13  JobRole                   1172 non-null   object
#  14  MonthlyIncome             1172 non-null   float64
#  15  NumCompaniesWorked        1172 non-null   float64
#  16  OverTime                  1172 non-null   object
#  17  PercentSalaryHike         1172 non-null   float64
#  18  RelationshipSatisfaction  1172 non-null   float64
#  19  Tools                     1172 non-null   object
#  20  TotalWorkingYears         1172 non-null   float64
#  21  Training                  1172 non-null   object
#  22  WorkLifeBalance           1172 non-null   float64
#  23  YearsAtCompany            1172 non-null   float64
#  24  YearsInCurrentRole        1172 non-null   float64
#  25  YearsSinceLastPromotion   1172 non-null   float64
#  26  YearsWithCurrManager      1172 non-null   float64
#  27  Performance               1172 non-null   int64
# dtypes: float64(13), int64(6), object(9)
# memory usage: 265.5+ KB

# %% [markdown]
# ## 4. Overall EDA

# %%
# --- Overall EDA using cleaned filtered_df ---
num_cols = filtered_df.select_dtypes(include=[np.number]).columns.tolist()

# Correlation heatmap
plt.figure(figsize=(10,8))
corr = filtered_df[num_cols].corr()
sns.heatmap(corr, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap (Numeric Variables)')
plt.tight_layout()
plt.show()

# %%
# Performance distribution
if 'Performance' in filtered_df.columns:
    plt.figure(figsize=(5,3))
    sns.histplot(filtered_df['Performance'], kde=True)
    plt.title('Performance Distribution (Cleaned)')
    plt.show()

filtered_df[num_cols].describe().T
# Out:
#                            count          mean           std     min  \
# Employee ID               1172.0  38120.523891  22474.144245    64.0
# Age                       1172.0     37.475256      9.222104    18.0
# DistanceFromHome          1172.0     12.952218      7.010260     1.0
# Education                 1172.0      3.015358      0.963786     1.0
# EnvironmentSatisfaction   1172.0      2.445392      1.107195     1.0
# JobInvolvement            1172.0      2.715870      0.702797     1.0
# JobLevel                  1172.0      2.157850      1.064848     1.0
# JobRotation               1172.0      2.045222      0.929911     1.0
# MonthlyIncome             1172.0   6751.798635   4239.202282  1009.0
# NumCompaniesWorked        1172.0      4.459044      2.777400     0.0
# PercentSalaryHike         1172.0     15.664676      3.444970    11.0
# RelationshipSatisfaction  1172.0      2.645904      1.098889     1.0
# TotalWorkingYears         1172.0     10.485495      7.082456     0.0
# WorkLifeBalance           1172.0      2.612628      0.793942     1.0
# YearsAtCompany            1172.0      6.803754      5.705172     0.0
# YearsInCurrentRole        1172.0      4.302048      3.319466     0.0
# YearsSinceLastPromotion   1172.0      2.148464      2.928141     0.0
# YearsWithCurrManager      1172.0      4.290102      3.302739     0.0
# Performance               1172.0     54.230375     15.562052     7.0
#
#                                25%      50%       75%      max
# Employee ID               18775.75  38538.0  57040.00  78280.0
# Age                          31.00     36.0     44.00     60.0
# DistanceFromHome              7.00     13.0     19.00     25.0
# Education                     3.00      3.0      4.00      5.0
# EnvironmentSatisfaction       1.00      2.0      3.00      4.0
# JobInvolvement                2.00      3.0      3.00      4.0
# JobLevel                      1.00      2.0      3.00      5.0
# JobRotation                   1.00      2.0      2.00      4.0
# MonthlyIncome              3368.25   5791.0   8912.50  19999.0
# NumCompaniesWorked            2.00      4.0      7.00      9.0
# PercentSalaryHike            13.00     15.0     18.00     25.0
# RelationshipSatisfaction      2.00      3.0      4.00      4.0
# TotalWorkingYears             6.00      9.0     12.25     40.0
# WorkLifeBalance               2.00      3.0      3.00      4.0
# YearsAtCompany                3.00      5.0      9.00     40.0
# YearsInCurrentRole            2.00      4.0      7.00     18.0
# YearsSinceLastPromotion       0.00      1.0      3.00     15.0
# YearsWithCurrManager          2.00      3.0      7.00     17.0
# Performance                  43.00     56.0     65.00     93.0

# %% [markdown]
# ## 5. EDA by Sub‑Question / Hypotheses

# %% [markdown]
# ### Sub‑Q1: Demographics → Age, Education, Gender vs Performance

# %%
# Sub-Q1: Demographics vs Performance
if 'Age' in filtered_df.columns and 'Performance' in filtered_df.columns:
    sns.lmplot(x='Age', y='Performance', data=filtered_df, scatter_kws={'s':15}, line_kws={'lw':2})
    plt.title('Age vs Performance (Cleaned)')
    plt.show()

if 'Education' in filtered_df.columns:
    plt.figure(figsize=(6,3))
    sns.boxplot(data=filtered_df, x='Education', y='Performance')
    plt.title('Education vs Performance (Cleaned)')
    plt.show()

if 'Gender' in filtered_df.columns:
    plt.figure(figsize=(5,3))
    sns.boxplot(data=filtered_df, x='Gender', y='Performance')
    plt.title('Gender vs Performance (Cleaned)')
    plt.show()

# %% [markdown]
# ### Sub‑Q2: Job experience & practices → Tenure, JobLevel, Mentoring/Training/OverTime

# %%
# Sub-Q2: Job experience & practices
if 'YearsAtCompany' in filtered_df.columns:
    sns.lmplot(x='YearsAtCompany', y='Performance', data=filtered_df, scatter_kws={'s':15}, line_kws={'lw':2})
    plt.title('YearsAtCompany vs Performance (Cleaned)')
    plt.show()

if 'JobLevel' in filtered_df.columns:
    plt.figure(figsize=(6,3))
    sns.boxplot(data=filtered_df, x='JobLevel', y='Performance')
    plt.title('JobLevel vs Performance (Cleaned)')
    plt.show()

for col in ['Mentoring', 'Training', 'OverTime']:
    if col in filtered_df.columns:
        plt.figure(figsize=(5,3))
        sns.boxplot(data=filtered_df, x=col, y='Performance')
        plt.title(f'{col} vs Performance (Cleaned)')
        plt.show()

# %% [markdown]
# ### Sub‑Q3: Satisfaction & Engagement → WLB, EnvSat, RelSat, JobInvolvement

# %%
# Sub-Q3: Satisfaction & engagement
sat_cols = [c for c in ['WorkLifeBalance','EnvironmentSatisfaction','RelationshipSatisfaction','JobInvolvement'] if c in filtered_df.columns]

records = []
for c in sat_cols:
    r = filtered_df[[c, 'Performance']].corr().iloc[0,1]
    records.append((c, r))
corr_df = pd.DataFrame(records, columns=['variable','r_with_performance']).sort_values('r_with_performance', ascending=False)

display(corr_df)

plt.figure(figsize=(6,3))
sns.barplot(data=corr_df, x='variable', y='r_with_performance')
plt.title('Correlation with Performance (Satisfaction/Engagement)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

for c in sat_cols:
    plt.figure(figsize=(5,3))
    sns.boxplot(data=filtered_df, x=c, y='Performance')
    plt.title(f'{c} vs Performance (Cleaned)')
    plt.show()
# Out:
#                    variable  r_with_performance
# 1   EnvironmentSatisfaction            0.070316
# 0           WorkLifeBalance            0.047663
# 3            JobInvolvement            0.013330
# 2  RelationshipSatisfaction            0.008869

# %% [markdown]
# ### Sub‑Q4: Tenure structure → YearsWithCurrManager & YearsSinceLastPromotion

# %%
# Sub-Q4: Tenure structure
for col in ['YearsWithCurrManager','YearsSinceLastPromotion']:
    if col in filtered_df.columns:
        sns.lmplot(x=col, y='Performance', data=filtered_df, scatter_kws={'s':15}, line_kws={'lw':2})
        plt.title(f'{col} vs Performance (Cleaned)')
        plt.show()

# %% [markdown]
# ## 6. Insights Summary

# %%
# Rank numeric predictors by correlation with performance (quick scan)
if 'Performance' in filtered_df.columns:
    num_cols = [c for c in filtered_df.select_dtypes(include=[np.number]).columns if c != 'Performance']
    corrs = filtered_df[num_cols].corrwith(filtered_df['Performance']).sort_values(ascending=False)
    insights = corrs.reset_index()
    insights.columns = ['variable','corr_with_performance']
    display(insights.head(10))
# Out:
#                   variable  corr_with_performance
# 0              JobRotation               0.366330
# 1            MonthlyIncome               0.126955
# 2                 JobLevel               0.106333
# 3           YearsAtCompany               0.074726
# 4  EnvironmentSatisfaction               0.070316
# 5        TotalWorkingYears               0.068872
# 6     YearsWithCurrManager               0.060174
# 7       YearsInCurrentRole               0.059107
# 8                      Age               0.053683
# 9          WorkLifeBalance               0.047663

# %%
    # Plot top 10 correlations
    plt.figure(figsize=(8,4))
    sns.barplot(data=insights.head(10), x='corr_with_performance', y='variable')
    plt.title('Top 10 Correlations with Performance')
    plt.xlabel('Correlation with Performance')
    plt.ylabel('Variable')
    plt.tight_layout()
    plt.show()
